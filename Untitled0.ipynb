# %% [markdown]
# <a href="https://colab.research.google.com/github/sharshsingh010-sys/collab-practical/blob/feature-login/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-c9247fd4-6274-4806-a82a-305521a5f778" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c9247fd4-6274-4806-a82a-305521a5f778">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install openpyxl

# %%
import pandas as pd

df = pd.read_excel("customer segmentation.xlsx")

df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income  Spending Score
# 0           1    Male   19             15              39
# 1           2    Male   21             15              81
# 2           3  Female   20             16               6

# %%
from sklearn.preprocessing import StandardScaler

X = df[['AnnualIncome', 'SpendingScore']]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1272/3812505263.py in <cell line: 0>()
#       1 from sklearn.preprocessing import StandardScaler
#       2
# ----> 3 X = df[['AnnualIncome', 'SpendingScore']]
#       4
#       5 scaler = StandardScaler()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
# ...

# %%
print(df.columns)
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income', 'Spending Score'], dtype='object')

# %%
X = df[['Annual Income', 'Spending Score']]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3, random_state=42)
df['Cluster'] = kmeans.fit_predict(X_scaled)

df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income  Spending Score  Cluster
# 0           1    Male   19             15              39        2
# 1           2    Male   21             15              81        0
# 2           3  Female   20             16               6        1

# %%
import matplotlib.pyplot as plt

plt.scatter(
    df['Annual Income'],
    df['Spending Score'],
    c=df['Cluster']
)

plt.xlabel("Annual Income")
plt.ylabel("Spending Score")
plt.title("Customer Segments")
plt.show()

# %%
df[['CustomerID', 'Annual Income', 'Spending Score', 'Cluster']].head()
# Out:
#    CustomerID  Annual Income  Spending Score  Cluster
# 0           1             15              39        2
# 1           2             15              81        0
# 2           3             16               6        1

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.scatter(
    df['Annual Income'],
    df['Spending Score'],
    c=df['Cluster'],
    cmap='viridis'
)

plt.xlabel("Annual Income")
plt.ylabel("Spending Score")
plt.title("Customer Segmentation")
plt.colorbar(label="Cluster")

plt.show()

# %%
df.groupby('Cluster')[['Annual Income', 'Spending Score']].mean()
# Out:
#          Annual Income  Spending Score
# Cluster
# 0                 15.0            81.0
# 1                 16.0             6.0
# 2                 15.0            39.0
